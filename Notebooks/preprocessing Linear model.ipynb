# %% [markdown]
# ## Problem - classify the loan_status variable (approved/not approved) for potential applicants

# %% [raw]
# person_age (Float): Age of the person
# person_gender (Categorical): Gender of the person
# person_education (Categorical): Highest education level
# person_income (Float): Annual income
# person_emp_exp (Integer): Years of employment experience
# person_home_ownership (Categorical): Home ownership status (e.g., rent, own, mortgage)
# loan_amnt (Float): Loan amount requested
# loan_intent (Float): Purpose of the loan
# loan_int_rate (Float): Loan interest rate
# loan_percent_income (Float): Loan amount as a percentage of annual income
# cb_person_cred_hist_length (Float): Length of credit history in years
# credit_score (Integer): Credit score of the person
# previous_loan_defaults_on_file (Categorical): Indicator of previous loan defaults
# loan_status : Loan approval status (Integer): 1 = approved; 0 = rejected

# %%
import pandas as pd  
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset  
df = pd.read_csv("loan_data.csv")

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# 1                 0.08                         2.0           504
# 2                 0.44                         3.0           635
# 3                 0.44                         2.0           675
# 4                 0.53                         4.0           586
#
#   previous_loan_defaults_on_file  loan_status
# 0                             No            1
# 1                            Yes            0
# 2                             No            1
# 3                             No            1
# 4                             No            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
#  12  previous_loan_defaults_on_file  45000 non-null  object
#  13  loan_status                     45000 non-null  int64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 4.8+ MB

# %%
df.columns
# Out:
# Index(['person_age', 'person_gender', 'person_education', 'person_income',
#        'person_emp_exp', 'person_home_ownership', 'loan_amnt', 'loan_intent',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'credit_score', 'previous_loan_defaults_on_file', 'loan_status'],
#       dtype='object')

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# 25%         8.590000             0.070000                    3.000000
# 50%        11.010000             0.120000                    4.000000
# 75%        12.990000             0.190000                    8.000000
# max        20.000000             0.660000                   30.000000
#
#        credit_score   loan_status
# count  45000.000000  45000.000000
# mean     632.608756      0.222222
# std       50.435865      0.415744
# min      390.000000      0.000000
# 25%      601.000000      0.000000
# 50%      640.000000      0.000000
# 75%      670.000000      0.000000
# max      850.000000      1.000000

# %%
#2 Checking duplicates

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# 0    35000
# 1    10000
# Name: count, dtype: int64

# %% [markdown]
# # EDA

# %%
# check class distribution loan approval

sns.countplot(x=df['loan_status'])
plt.title('Loan Status Distribution')
plt.show()

# %%
# Check outliers

plt.figure(figsize=(10,6))
sns.boxplot(data=df[['person_age', 'person_income', 'person_emp_exp', 'loan_amnt', 'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length', 'credit_score']])
plt.xticks(rotation=45)
plt.title('Boxplot of numerical features')
plt.show()

# %% [markdown]
# ## Handling outliers

# %%
# Applying Log transformation to person_income to reduce skewness

df['person_income'] = np.log1p(df['person_income'])

# %%
df['person_gender'].value_counts()
# Out:
# person_gender
# male      24841
# female    20159
# Name: count, dtype: int64

# %%
df['person_education'].value_counts()
# Out:
# person_education
# Bachelor       13399
# Associate      12028
# High School    11972
# Master          6980
# Doctorate        621
# Name: count, dtype: int64

# %%
df['person_home_ownership'].value_counts()
# Out:
# person_home_ownership
# RENT        23443
# MORTGAGE    18489
# OWN          2951
# OTHER         117
# Name: count, dtype: int64

# %%
df['loan_intent'].value_counts()
# Out:
# loan_intent
# EDUCATION            9153
# MEDICAL              8548
# VENTURE              7819
# PERSONAL             7552
# DEBTCONSOLIDATION    7145
# HOMEIMPROVEMENT      4783
# Name: count, dtype: int64

# %%
df['previous_loan_defaults_on_file'].value_counts()
# Out:
# previous_loan_defaults_on_file
# Yes    22858
# No     22142
# Name: count, dtype: int64

# %%
# One-Hot Encoding for multi-category features
df = pd.get_dummies(df, columns=['person_education', 'person_home_ownership',
                                 'loan_intent', 'previous_loan_defaults_on_file'],drop_first=True)


# Binary Encoding for gender
df['person_gender'] = df['person_gender'].map({'female':0 , 'male':1})

# %%
# Converting bool datatype to int 

bool_columns = df.select_dtypes(include=['bool']).columns

df[bool_columns] = df[bool_columns].astype(int)

# %%
df.head()
# Out:
#    person_age  person_gender  person_income  person_emp_exp  loan_amnt  \
# 0        22.0              0      11.183713               0    35000.0
# 1        21.0              0       9.415971               0     1000.0
# 2        25.0              0       9.428592               3     5500.0
# 3        23.0              0      11.286702               0    35000.0
# 4        24.0              1      11.099469               1    35000.0
#
#    loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0          16.02                 0.49                         3.0
# 1          11.14                 0.08                         2.0
# 2          12.87                 0.44                         3.0
# 3          15.23                 0.44                         2.0
# 4          14.27                 0.53                         4.0
#
#    credit_score  loan_status  ...  person_education_Master  \
# 0           561            1  ...                        1
# 1           504            0  ...                        0
# 2           635            1  ...                        0
# 3           675            1  ...                        0
# 4           586            1  ...                        1
#
#    person_home_ownership_OTHER  person_home_ownership_OWN  \
# 0                            0                          0
# 1                            0                          1
# 2                            0                          0
# 3                            0                          0
# 4                            0                          0
#
#    person_home_ownership_RENT  loan_intent_EDUCATION  \
# 0                           1                      0
# 1                           0                      1
# 2                           0                      0
# 3                           1                      0
# 4                           1                      0
#
#    loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 0                            0                    0                     1
# 1                            0                    0                     0
# 2                            0                    1                     0
# 3                            0                    1                     0
# 4                            0                    1                     0
#
#    loan_intent_VENTURE  previous_loan_defaults_on_file_Yes
# 0                    0                                   0
# 1                    0                                   1
# 2                    0                                   0
# 3                    0                                   0
# 4                    0                                   0
#
# [5 rows x 23 columns]

# %%
#4 checking correlation

plt.figure(figsize=(40,40))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('feature correlation Heatmap')
plt.show()

# %%
df.corr()
# Out:
#                                     person_age  person_gender  person_income  \
# person_age                            1.000000       0.017528       0.131005
# person_gender                         0.017528       1.000000       0.011223
# person_income                         0.131005       0.011223       1.000000
# person_emp_exp                        0.954412       0.015078       0.118452
# loan_amnt                             0.050750       0.010647       0.422789
# loan_int_rate                         0.013402       0.003662      -0.019272
# loan_percent_income                  -0.043299      -0.000367      -0.360581
# cb_person_cred_hist_length            0.861985       0.011999       0.103123
# credit_score                          0.178432      -0.000223       0.028839
# loan_status                          -0.021476      -0.000561      -0.283465
# person_education_Bachelor            -0.054982      -0.001519      -0.001687
# person_education_Doctorate            0.113329       0.001224       0.009935
# person_education_High School          0.004769       0.002244      -0.007590
# person_education_Master              -0.020228      -0.004088       0.008414
# person_home_ownership_OTHER          -0.007321       0.002118       0.007742
# person_home_ownership_OWN            -0.003848       0.001802      -0.092466
# person_home_ownership_RENT           -0.035974      -0.001794      -0.328023
# loan_intent_EDUCATION                -0.082782       0.002369      -0.008121
# loan_intent_HOMEIMPROVEMENT           0.068081       0.000388       0.073580
# loan_intent_MEDICAL                   0.016351      -0.006344      -0.072479
# loan_intent_PERSONAL                  0.026834      -0.001300       0.014131
# loan_intent_VENTURE                  -0.006695       0.001502       0.006733
# previous_loan_defaults_on_file_Yes   -0.025917       0.000704       0.144924
#
#                                     person_emp_exp  loan_amnt  loan_int_rate  \
# person_age                                0.954412   0.050750       0.013402
# person_gender                             0.015078   0.010647       0.003662
# person_income                             0.118452   0.422789      -0.019272
# person_emp_exp                            1.000000   0.044589       0.016631
# loan_amnt                                 0.044589   1.000000       0.146093
# loan_int_rate                             0.016631   0.146093       1.000000
# loan_percent_income                      -0.039862   0.593011       0.125209
# cb_person_cred_hist_length                0.824272   0.042969       0.018008
# credit_score                              0.186196   0.009074       0.011498
# loan_status                              -0.020481   0.107714       0.332005
# person_education_Bachelor                -0.055182  -0.002789       0.006201
# person_education_Doctorate                0.106693   0.006515       0.002393
# person_education_High School              0.008373  -0.003788      -0.001579
# person_education_Master                  -0.019723   0.000806      -0.000555
# person_home_ownership_OTHER              -0.004535   0.013738       0.017592
# person_home_ownership_OWN                 0.000490  -0.025290      -0.015953
# person_home_ownership_RENT               -0.034499  -0.136521       0.130044
# loan_intent_EDUCATION                    -0.072846  -0.006062      -0.017332
# loan_intent_HOMEIMPROVEMENT               0.058164   0.045657       0.022505
# loan_intent_MEDICAL                       0.016102  -0.034140       0.012609
# loan_intent_PERSONAL                      0.026863   0.001476      -0.004051
# loan_intent_VENTURE                      -0.006156   0.005500      -0.013177
# previous_loan_defaults_on_file_Yes       -0.029231  -0.059009      -0.181800
#
#                                     loan_percent_income  \
# person_age                                    -0.043299
# person_gender                                 -0.000367
# person_income                                 -0.360581
# person_emp_exp                                -0.039862
# loan_amnt                                      0.593011
# loan_int_rate                                  0.125209
# loan_percent_income                            1.000000
# cb_person_cred_hist_length                    -0.031868
# credit_score                                  -0.011483
# loan_status                                    0.384880
# person_education_Bachelor                      0.002193
# person_education_Doctorate                     0.000395
# person_education_High School                   0.000100
# person_education_Master                       -0.007982
# person_home_ownership_OTHER                    0.011520
# person_home_ownership_OWN                      0.052900
# person_home_ownership_RENT                     0.125282
# loan_intent_EDUCATION                         -0.001033
# loan_intent_HOMEIMPROVEMENT                   -0.015604
# loan_intent_MEDICAL                            0.020547
# loan_intent_PERSONAL                          -0.007713
# loan_intent_VENTURE                            0.001601
# previous_loan_defaults_on_file_Yes            -0.203252
#
#                                     cb_person_cred_hist_length  credit_score  \
# person_age                                            0.861985      0.178432
# person_gender                                         0.011999     -0.000223
# person_income                                         0.103123      0.028839
# person_emp_exp                                        0.824272      0.186196
# loan_amnt                                             0.042969      0.009074
# loan_int_rate                                         0.018008      0.011498
# loan_percent_income                                  -0.031868     -0.011483
# cb_person_cred_hist_length                            1.000000      0.155204
# credit_score                                          0.155204      1.000000
# loan_status                                          -0.014851     -0.007647
# person_education_Bachelor                            -0.059117      0.075384
# person_education_Doctorate                            0.109456      0.082868
# person_education_High School                          0.005968     -0.164695
# person_education_Master                              -0.019320      0.126385
# person_home_ownership_OTHER                          -0.006692     -0.004865
# person_home_ownership_OWN                            -0.000855     -0.002891
# person_home_ownership_RENT                           -0.027891     -0.005051
# loan_intent_EDUCATION                                -0.070653     -0.015508
# loan_intent_HOMEIMPROVEMENT                           0.054821      0.010228
# loan_intent_MEDICAL                                   0.013298      0.003359
# loan_intent_PERSONAL                                  0.027952      0.003795
# loan_intent_VENTURE                                  -0.004942      0.009705
# previous_loan_defaults_on_file_Yes                   -0.022640     -0.183005
#
#                                     loan_status  ...  person_education_Master  \
# person_age                            -0.021476  ...                -0.020228
# person_gender                         -0.000561  ...                -0.004088
# person_income                         -0.283465  ...                 0.008414
# person_emp_exp                        -0.020481  ...                -0.019723
# loan_amnt                              0.107714  ...                 0.000806
# loan_int_rate                          0.332005  ...                -0.000555
# loan_percent_income                    0.384880  ...                -0.007982
# cb_person_cred_hist_length            -0.014851  ...                -0.019320
# credit_score                          -0.007647  ...                 0.126385
# loan_status                            1.000000  ...                -0.004741
# person_education_Bachelor              0.004728  ...                -0.279002
# person_education_Doctorate             0.001833  ...                -0.050685
# person_education_High School           0.001277  ...                -0.257967
# person_education_Master               -0.004741  ...                 1.000000
# person_home_ownership_OTHER            0.013645  ...                -0.008616
# person_home_ownership_OWN             -0.093666  ...                 0.008746
# person_home_ownership_RENT             0.255239  ...                -0.003105
# loan_intent_EDUCATION                 -0.064006  ...                -0.007737
# loan_intent_HOMEIMPROVEMENT            0.033838  ...                 0.005996
# loan_intent_MEDICAL                    0.065195  ...                 0.008155
# loan_intent_PERSONAL                  -0.022488  ...                -0.005322
# loan_intent_VENTURE                   -0.085992  ...                 0.002298
# previous_loan_defaults_on_file_Yes    -0.543096  ...                -0.021184
#
#                                     person_home_ownership_OTHER  \
# person_age                                            -0.007321
# person_gender                                          0.002118
# person_income                                          0.007742
# person_emp_exp                                        -0.004535
# loan_amnt                                              0.013738
# loan_int_rate                                          0.017592
# loan_percent_income                                    0.011520
# cb_person_cred_hist_length                            -0.006692
# credit_score                                          -0.004865
# loan_status                                            0.013645
# person_education_Bachelor                              0.005881
# person_education_Doctorate                            -0.002299
# person_education_High School                          -0.002101
# person_education_Master                               -0.008616
# person_home_ownership_OTHER                            1.000000
# person_home_ownership_OWN                             -0.013526
# person_home_ownership_RENT                            -0.053243
# loan_intent_EDUCATION                                 -0.006285
# loan_intent_HOMEIMPROVEMENT                           -0.000617
# loan_intent_MEDICAL                                   -0.001363
# loan_intent_PERSONAL                                   0.002761
# loan_intent_VENTURE                                    0.007683
# previous_loan_defaults_on_file_Yes                    -0.010851
#
#                                     person_home_ownership_OWN  \
# person_age                                          -0.003848
# person_gender                                        0.001802
# person_income                                       -0.092466
# person_emp_exp                                       0.000490
# loan_amnt                                           -0.025290
# loan_int_rate                                       -0.015953
# loan_percent_income                                  0.052900
# cb_person_cred_hist_length                          -0.000855
# credit_score                                        -0.002891
# loan_status                                         -0.093666
# person_education_Bachelor                           -0.004845
# person_education_Doctorate                           0.002521
# person_education_High School                        -0.005911
# person_education_Master                              0.008746
# person_home_ownership_OTHER                         -0.013526
# person_home_ownership_OWN                            1.000000
# person_home_ownership_RENT                          -0.276261
# loan_intent_EDUCATION                                0.003070
# loan_intent_HOMEIMPROVEMENT                          0.010294
# loan_intent_MEDICAL                                 -0.016148
# loan_intent_PERSONAL                                 0.004986
# loan_intent_VENTURE                                  0.091038
# previous_loan_defaults_on_file_Yes                   0.053156
#
#                                     person_home_ownership_RENT  \
# person_age                                           -0.035974
# person_gender                                        -0.001794
# person_income                                        -0.328023
# person_emp_exp                                       -0.034499
# loan_amnt                                            -0.136521
# loan_int_rate                                         0.130044
# loan_percent_income                                   0.125282
# cb_person_cred_hist_length                           -0.027891
# credit_score                                         -0.005051
# loan_status                                           0.255239
# person_education_Bachelor                             0.007949
# person_education_Doctorate                           -0.010491
# person_education_High School                          0.001723
# person_education_Master                              -0.003105
# person_home_ownership_OTHER                          -0.053243
# person_home_ownership_OWN                            -0.276261
# person_home_ownership_RENT                            1.000000
# loan_intent_EDUCATION                                 0.002508
# loan_intent_HOMEIMPROVEMENT                          -0.054951
# loan_intent_MEDICAL                                   0.061676
# loan_intent_PERSONAL                                 -0.014433
# loan_intent_VENTURE                                  -0.037610
# previous_loan_defaults_on_file_Yes                   -0.138273
#
#                                     loan_intent_EDUCATION  \
# person_age                                      -0.082782
# person_gender                                    0.002369
# person_income                                   -0.008121
# person_emp_exp                                  -0.072846
# loan_amnt                                       -0.006062
# loan_int_rate                                   -0.017332
# loan_percent_income                             -0.001033
# cb_person_cred_hist_length                      -0.070653
# credit_score                                    -0.015508
# loan_status                                     -0.064006
# person_education_Bachelor                       -0.002458
# person_education_Doctorate                      -0.014817
# person_education_High School                     0.014354
# person_education_Master                         -0.007737
# person_home_ownership_OTHER                     -0.006285
# person_home_ownership_OWN                        0.003070
# person_home_ownership_RENT                       0.002508
# loan_intent_EDUCATION                            1.000000
# loan_intent_HOMEIMPROVEMENT                     -0.174261
# loan_intent_MEDICAL                             -0.244696
# loan_intent_PERSONAL                            -0.226920
# loan_intent_VENTURE                             -0.231724
# previous_loan_defaults_on_file_Yes               0.038725
#
#                                     loan_intent_HOMEIMPROVEMENT  \
# person_age                                             0.068081
# person_gender                                          0.000388
# person_income                                          0.073580
# person_emp_exp                                         0.058164
# loan_amnt                                              0.045657
# loan_int_rate                                          0.022505
# loan_percent_income                                   -0.015604
# cb_person_cred_hist_length                             0.054821
# credit_score                                           0.010228
# loan_status                                            0.033838
# person_education_Bachelor                             -0.010748
# person_education_Doctorate                             0.010503
# person_education_High School                          -0.012481
# person_education_Master                                0.005996
# person_home_ownership_OTHER                           -0.000617
# person_home_ownership_OWN                              0.010294
# person_home_ownership_RENT                            -0.054951
# loan_intent_EDUCATION                                 -0.174261
# loan_intent_HOMEIMPROVEMENT                            1.000000
# loan_intent_MEDICAL                                   -0.167000
# loan_intent_PERSONAL                                  -0.154868
# loan_intent_VENTURE                                   -0.158147
# previous_loan_defaults_on_file_Yes                    -0.021713
#
#                                     loan_intent_MEDICAL  loan_intent_PERSONAL  \
# person_age                                     0.016351              0.026834
# person_gender                                 -0.006344             -0.001300
# person_income                                 -0.072479              0.014131
# person_emp_exp                                 0.016102              0.026863
# loan_amnt                                     -0.034140              0.001476
# loan_int_rate                                  0.012609             -0.004051
# loan_percent_income                            0.020547             -0.007713
# cb_person_cred_hist_length                     0.013298              0.027952
# credit_score                                   0.003359              0.003795
# loan_status                                    0.065195             -0.022488
# person_education_Bachelor                     -0.003124              0.003687
# person_education_Doctorate                     0.007788              0.002438
# person_education_High School                   0.000109             -0.000830
# person_education_Master                        0.008155             -0.005322
# person_home_ownership_OTHER                   -0.001363              0.002761
# person_home_ownership_OWN                     -0.016148              0.004986
# person_home_ownership_RENT                     0.061676             -0.014433
# loan_intent_EDUCATION                         -0.244696             -0.226920
# loan_intent_HOMEIMPROVEMENT                   -0.167000             -0.154868
# loan_intent_MEDICAL                            1.000000             -0.217464
# loan_intent_PERSONAL                          -0.217464              1.000000
# loan_intent_VENTURE                           -0.222068             -0.205936
# previous_loan_defaults_on_file_Yes            -0.034562              0.004153
#
#                                     loan_intent_VENTURE  \
# person_age                                    -0.006695
# person_gender                                  0.001502
# person_income                                  0.006733
# person_emp_exp                                -0.006156
# loan_amnt                                      0.005500
# loan_int_rate                                 -0.013177
# loan_percent_income                            0.001601
# cb_person_cred_hist_length                    -0.004942
# credit_score                                   0.009705
# loan_status                                   -0.085992
# person_education_Bachelor                      0.001648
# person_education_Doctorate                    -0.000454
# person_education_High School                   0.001566
# person_education_Master                        0.002298
# person_home_ownership_OTHER                    0.007683
# person_home_ownership_OWN                      0.091038
# person_home_ownership_RENT                    -0.037610
# loan_intent_EDUCATION                         -0.231724
# loan_intent_HOMEIMPROVEMENT                   -0.158147
# loan_intent_MEDICAL                           -0.222068
# loan_intent_PERSONAL                          -0.205936
# loan_intent_VENTURE                            1.000000
# previous_loan_defaults_on_file_Yes             0.052122
#
#                                     previous_loan_defaults_on_file_Yes
# person_age                                                   -0.025917
# person_gender                                                 0.000704
# person_income                                                 0.144924
# person_emp_exp                                               -0.029231
# loan_amnt                                                    -0.059009
# loan_int_rate                                                -0.181800
# loan_percent_income                                          -0.203252
# cb_person_cred_hist_length                                   -0.022640
# credit_score                                                 -0.183005
# loan_status                                                  -0.543096
# person_education_Bachelor                                    -0.017507
# person_education_Doctorate                                   -0.019600
# person_education_High School                                  0.029650
# person_education_Master                                      -0.021184
# person_home_ownership_OTHER                                  -0.010851
# person_home_ownership_OWN                                     0.053156
# person_home_ownership_RENT                                   -0.138273
# loan_intent_EDUCATION                                         0.038725
# loan_intent_HOMEIMPROVEMENT                                  -0.021713
# loan_intent_MEDICAL                                          -0.034562
# loan_intent_PERSONAL                                          0.004153
# loan_intent_VENTURE                                           0.052122
# previous_loan_defaults_on_file_Yes                            1.000000
#
# [23 rows x 23 columns]

# %%
# Correlation greater than 0.8

corr_matrix = df.corr()

high_corr = corr_matrix[corr_matrix > 0.8]

# Excluding self-correlation(diagonal values)
np.fill_diagonal(high_corr.values, np.nan)

# drop row /columns with all NaN values (no high correlation)
high_corr = high_corr.dropna(how='all').dropna(axis=1, how='all')

# %%
high_corr
# Out:
#                             person_age  person_emp_exp  \
# person_age                         NaN        0.954412
# person_emp_exp                0.954412             NaN
# cb_person_cred_hist_length    0.861985        0.824272
#
#                             cb_person_cred_hist_length
# person_age                                    0.861985
# person_emp_exp                                0.824272
# cb_person_cred_hist_length                         NaN

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import numpy as np

num_features = ['person_age', 'person_income', 'loan_amnt', 'loan_int_rate', 
                'loan_percent_income', 'cb_person_cred_hist_length', 'credit_score']

# Createing DataFrame for VIF
X_vif = df[num_features]

#VIF
vif_data = pd.DataFrame()
vif_data["Feature"] = X_vif.columns
vif_data["VIF"] = [variance_inflation_factor(X_vif.values, i) for i in range(len(X_vif.columns))]

# Display VIF
print(vif_data)
# Out:
#                       Feature         VIF
# 0                  person_age   86.786025
# 1               person_income  182.179020
# 2                   loan_amnt    6.593165
# 3               loan_int_rate   14.728341
# 4         loan_percent_income    6.515611
# 5  cb_person_cred_hist_length   12.669231
# 6                credit_score  151.390769

# %%
from sklearn.preprocessing import StandardScaler

# Define numerical columns
num_cols = ['person_age', 'person_income', 'loan_amnt', 'loan_int_rate', 
            'loan_percent_income','cb_person_cred_hist_length', 'credit_score']

# Apply Standardization
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import numpy as np

num_features = ['person_age', 'person_income', 'loan_amnt', 'loan_int_rate', 
                'loan_percent_income', 'cb_person_cred_hist_length', 'credit_score']

# Createing DataFrame for VIF
X_vif = df[num_features]

#VIF
vif_data = pd.DataFrame()
vif_data["Feature"] = X_vif.columns
vif_data["VIF"] = [variance_inflation_factor(X_vif.values, i) for i in range(len(X_vif.columns))]

# Display VIF
print(vif_data)
# Out:
#                       Feature       VIF
# 0                  person_age  3.950560
# 1               person_income  4.147914
# 2                   loan_amnt  5.569466
# 3               loan_int_rate  1.033398
# 4         loan_percent_income  5.188113
# 5  cb_person_cred_hist_length  3.893609
# 6                credit_score  1.033037

# %%
df.head()
# Out:
#    person_age  person_gender  person_income  person_emp_exp  loan_amnt  \
# 0   -0.953538              0       0.109877               0   4.024953
# 1   -1.118963              0      -3.060977               0  -1.359209
# 2   -0.457264              0      -3.038339               3  -0.646600
# 3   -0.788113              0       0.294612               0   4.024953
# 4   -0.622689              1      -0.041235               1   4.024953
#
#    loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0       1.683039             4.016394                   -0.739109
# 1       0.044782            -0.684829                   -0.996863
# 2       0.625557             3.443074                   -0.739109
# 3       1.417829             3.443074                   -0.996863
# 4       1.095549             4.475050                   -0.481354
#
#    credit_score  loan_status  ...  person_education_Master  \
# 0     -1.419814            1  ...                        1
# 1     -2.549975            0  ...                        0
# 2      0.047412            1  ...                        0
# 3      0.840507            1  ...                        0
# 4     -0.924130            1  ...                        1
#
#    person_home_ownership_OTHER  person_home_ownership_OWN  \
# 0                            0                          0
# 1                            0                          1
# 2                            0                          0
# 3                            0                          0
# 4                            0                          0
#
#    person_home_ownership_RENT  loan_intent_EDUCATION  \
# 0                           1                      0
# 1                           0                      1
# 2                           0                      0
# 3                           1                      0
# 4                           1                      0
#
#    loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 0                            0                    0                     1
# 1                            0                    0                     0
# 2                            0                    1                     0
# 3                            0                    1                     0
# 4                            0                    1                     0
#
#    loan_intent_VENTURE  previous_loan_defaults_on_file_Yes
# 0                    0                                   0
# 1                    0                                   1
# 2                    0                                   0
# 3                    0                                   0
# 4                    0                                   0
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   person_age                          45000 non-null  float64
#  1   person_gender                       45000 non-null  int64
#  2   person_income                       45000 non-null  float64
#  3   person_emp_exp                      45000 non-null  int64
#  4   loan_amnt                           45000 non-null  float64
#  5   loan_int_rate                       45000 non-null  float64
#  6   loan_percent_income                 45000 non-null  float64
#  7   cb_person_cred_hist_length          45000 non-null  float64
#  8   credit_score                        45000 non-null  float64
#  9   loan_status                         45000 non-null  int64
#  10  person_education_Bachelor           45000 non-null  int64
#  11  person_education_Doctorate          45000 non-null  int64
#  12  person_education_High School        45000 non-null  int64
#  13  person_education_Master             45000 non-null  int64
#  14  person_home_ownership_OTHER         45000 non-null  int64
#  15  person_home_ownership_OWN           45000 non-null  int64
#  16  person_home_ownership_RENT          45000 non-null  int64
#  17  loan_intent_EDUCATION               45000 non-null  int64
#  18  loan_intent_HOMEIMPROVEMENT         45000 non-null  int64
#  19  loan_intent_MEDICAL                 45000 non-null  int64
#  20  loan_intent_PERSONAL                45000 non-null  int64
#  21  loan_intent_VENTURE                 45000 non-null  int64
#  22  previous_loan_defaults_on_file_Yes  45000 non-null  int64
# dtypes: float64(7), int64(16)
# memory usage: 7.9 MB

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# 0    35000
# 1    10000
# Name: count, dtype: int64

# %% [markdown]
# # Saving cleaned data

# %%
df.to_csv('Cleaned_data_Linear.csv', index=False)
